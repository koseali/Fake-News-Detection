# %%
import twint 
import nest_asyncio
nest_asyncio.apply()
c = twint.Config()

# %%
c.Lang = "tr"
c.Store_csv = True
c.Output = "./Deneme.csv"
x = 1
c.Filter_retweets = True
c.Min_likes = 10 * x
c.Min_retweets = 3 * x
c.Min_replies = x
c.Search = "#asgariucret"
c.Since ='2020-12-22 00:00:00'
c.Until = '2020-12-30 00:00:00'

# %%
twint.run.Search(c)
# Out:
# 1343999550487408649 2020-12-29 22:17:17 +0300 <NaciyeKaplan13> #asgariucret 👇👇  https://t.co/IVi494YYae
# 1343962582214959105 2020-12-29 19:50:23 +0300 <SahinalpBulent> Son 1 yıl içerisinde, temel gıda ürünleri olan; -yumurta %76,  -domates %68,  -kuru soğan %38  -mercimek %67,  -ayçiçek yağı % 43  -et % 37,  -un ve ekmek ort. %25 zamlanırken, #asgariucret %21,5 artış ile 2.825,90 TL oldu.
# 1343928518200205314 2020-12-29 17:35:02 +0300 <Rehber_Gazetesi> 30.12.2020 Manşetimiz... #AylinSözer #asgariucret #VETO #çinaşısı #IrkçıSedaAkgül #2020yeBirSözBırak @btmnbld @batmanvaliligi @ZehraZumrutS @suleymansoylu @hcemal571 @haksiad72  https://t.co/0PBGPKDgRl
# 1343910287066468353 2020-12-29 16:22:35 +0300 <Skara_5734> Almanya da en düşük ücret yaklaşık 1500 €, saat ücreti 9,35€. Yani bir Alman vatandaşı asgari ücretle 1500 şişe litrelik yağ alabilirken, Türkiye'de asgari ücret 2825 lira oldu. Biz burda o parayla ancak 190 şişe litrelik yağ alabiliyoruz,   #asgariucret #yağ
# ...

# %%
import pandas as pd

# %%
data = pd.read_csv("./Deneme.csv")

# %%
pd.set_option("display.max_rows", 2800, "display.max_columns", 100)

# %%
data.head()
# Out:
#                     id      conversation_id  \
# 0  1343999550487408649  1343999550487408649
# 1  1343962582214959105  1343962582214959105
# 2  1343928518200205314  1343928518200205314
# 3  1343910287066468353  1343910287066468353
# 4  1343903949993213952  1343903949993213952
#
#                                    created_at        date      time  timezone  \
# 0  2020-12-29 22:17:17 Türkiye Standart Saati  2020-12-29  22:17:17       300
# 1  2020-12-29 19:50:23 Türkiye Standart Saati  2020-12-29  19:50:23       300
# 2  2020-12-29 17:35:02 Türkiye Standart Saati  2020-12-29  17:35:02       300
# 3  2020-12-29 16:22:35 Türkiye Standart Saati  2020-12-29  16:22:35       300
# 4  2020-12-29 15:57:24 Türkiye Standart Saati  2020-12-29  15:57:24       300
#
#                user_id         username                             name  \
# 0  1116376072864641026   naciyekaplan13                    Naciye Kaplan
# 1  1249691032893227008   sahinalpbulent                  Bülent Şahinalp
# ...
